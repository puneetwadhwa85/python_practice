# %%
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
chipo=pd.read_excel('D:\\python_practice\\chipo.xlsx')

# %%
chipo.head(10)
# Out:
#    order_id  quantity  item_name choice_description       item_price  \
# 0         1         1      Chips                and            Fresh
# 1         1         1       Izze       [Clementine]            $3.39
# 2         1         1  Nantucket             Nectar          [Apple]
# 3         1         1      Chips                and  Tomatillo-Green
# 4         2         2    Chicken               Bowl   [Tomatillo-Red
# 5         3         1    Chicken               Bowl           [Fresh
# 6         3         1       Side                 of            Chips
# 7         4         1      Steak            Burrito       [Tomatillo
# 8         4         1      Steak               Soft            Tacos
# 9         5         1      Steak            Burrito           [Fresh
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 21  \
# 0      Tomato      Salsa        NaN      $2.39          NaN  ...         NaN
# ...

# %%
chipo.shape[0:1]
# Out:
# (4622,)

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 31 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    4411 non-null object
# item_price            4460 non-null object
# Unnamed: 5            3811 non-null object
# Unnamed: 6            4204 non-null object
# Unnamed: 7            3145 non-null object
# Unnamed: 8            3057 non-null object
# Unnamed: 9            2919 non-null object
# Unnamed: 10           2755 non-null object
# Unnamed: 11           2619 non-null object
# Unnamed: 12           2391 non-null object
# Unnamed: 13           2066 non-null object
# Unnamed: 14           1646 non-null object
# Unnamed: 15           1192 non-null object
# Unnamed: 16           740 non-null object
# Unnamed: 17           430 non-null object
# Unnamed: 18           269 non-null object
# ...

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
a=chipo.groupby('item_name')
a=a.sum()
a=a.sort_values(['quantity'], ascending=False)
a.head()
# Out:
#            order_id  quantity
# item_name
# Chicken     1484575      1654
# Chips        918018      1061
# Steak        640136       734
# Canned       381149       477
# Veggie       183988       217

# %%
cd=chipo.groupby('choice_description')
cd=cd.sum()
cd=cd.sort_values(['quantity'], ascending=False)
cd.head()
# Out:
#                     order_id  quantity
# choice_description
# Burrito              1033072      1225
# Bowl                 1096662      1206
# and                   710014       831
# Soft                  515243       600
# Water                 175944       211

# %%
total=chipo.quantity.sum()
total
# Out:
# 4972

# %%
chipo.item_price.dtype
# Out:
# dtype('O')
